# %%
import csv
import pandas as pd

db = r'C:/Users/goura/Documents/Kopal Rastogi/chatbot/COVID_Question_Answers.xlsx'

# %%
df = pd.read_excel(db)
df.head()
df.drop(['Location', 'Source'], axis=1)
# Out:
#       Id                                          Questions  \
# 0      1  What is the incubation period of the corona vi...
# 1      2  Who is most at risk for the corona virus disease?
# 2      3      Is the corona virus disease the same as SARS?
# 3      4                            What is a corona virus?
# 4      5  Can humans become infected with a novel corona...
# ..   ...                                                ...
# 201  202  Do I need to wear a mask every time I step out...
# 202  203  What is the government doing to contain the sp...
# 203  204  Where can I go to obtain accurate, scientific,...
# 204  205  How long is the incubation period for corona v...
# 205  206  What do we know about incubation period of cor...
#
#                                                Answers
# 0    The “incubation period” means the time between...
# 1    People of all ages can be infected by the new ...
# 2    No. The virus that causes COVID-19 and the one...
# ...

# %%
for index, row in df.iterrows():
    print('- intent: ques_{:03d}'.format(index+1))
    print('  examples: |')
    print('  - ', row['Questions'])
    print()
# Out:
# - intent: ques_001
#   examples: |
#   -  What is the incubation period of the corona virus disease?
#
# - intent: ques_002
#   examples: |
#   -  Who is most at risk for the corona virus disease?
#
# - intent: ques_003
#   examples: |
#   -  Is the corona virus disease the same as SARS?
#
# - intent: ques_004
#   examples: |
#   -  What is a corona virus?
#
# - intent: ques_005
#   examples: |
#   -  Can humans become infected with a novel corona virus of animal source?
#
# - intent: ques_006
#   examples: |
#   -  What are the symptoms of someone infected with a corona virus?
#
# - intent: ques_007
#   examples: |
#   -  Can corona viruse be transmitted from person to person?
#
# - intent: ques_008
#   examples: |
#   -  Is there a vaccine for a novel corona virus?
#
# - intent: ques_009
#   examples: |
#   -  Is there a treatment for a novel corona virus?
#
# - intent: ques_010
#   examples: |
#   -  What can I do to protect myself?
#
# - intent: ques_011
#   examples: |
# ...

# %%
for index, row in df.iterrows():
    print('  utter_ques_{:03d}:'.format(index+1))
    print('  - text: ', row['Answers'])
    print()
# Out:
#   utter_ques_001:
#   - text:  The “incubation period” means the time between catching the virus and beginning to have symptoms of the disease. Most estimates of the incubation period for COVID-19 range from 1-14 days, most commonly around five days. These estimates will be updated as more data become available.
#
#   utter_ques_002:
#   - text:  People of all ages can be infected by the new corona virus (2019-nCoV). Older people, and people with pre-existing medical conditions (such as asthma, diabetes, heart disease) appear to be more vulnerable to becoming severely ill with the virus.WHO advises people of all ages to take steps to protect themselves from the virus, for example by following good hand hygiene and good respiratory hygiene.
#
#   utter_ques_003:
#   - text:  No. The virus that causes COVID-19 and the one that caused the outbreak of Severe Acute Respiratory Syndrome (SARS) in 2003 are related to each other genetically, but the diseases they cause are quite different.
# ...

# %%
for index, row in df.iterrows():
    print('- rule: Ans_Ques_{:03d}'.format(index+1))
    print('  steps:')
    print('  - intent: ques_{:03d}'.format(index+1))
    print('  - action: utter_ques_{:03d}'.format(index+1))
    print()
# Out:
# - rule: Ans_Ques_001
#   steps:
#   - intent: ques_001
#   - action: utter_ques_001
#
# - rule: Ans_Ques_002
#   steps:
#   - intent: ques_002
#   - action: utter_ques_002
#
# - rule: Ans_Ques_003
#   steps:
#   - intent: ques_003
#   - action: utter_ques_003
#
# - rule: Ans_Ques_004
#   steps:
#   - intent: ques_004
#   - action: utter_ques_004
#
# - rule: Ans_Ques_005
#   steps:
#   - intent: ques_005
#   - action: utter_ques_005
#
# - rule: Ans_Ques_006
#   steps:
#   - intent: ques_006
#   - action: utter_ques_006
#
# - rule: Ans_Ques_007
#   steps:
#   - intent: ques_007
#   - action: utter_ques_007
#
# - rule: Ans_Ques_008
#   steps:
#   - intent: ques_008
#   - action: utter_ques_008
#
# - rule: Ans_Ques_009
#   steps:
#   - intent: ques_009
#   - action: utter_ques_009
#
# - rule: Ans_Ques_010
#   steps:
#   - intent: ques_010
#   - action: utter_ques_010
#
# - rule: Ans_Ques_011
#   steps:
#   - intent: ques_011
#   - action: utter_ques_011
#
# - rule: Ans_Ques_012
# ...

# %%
for index, row in df.iterrows():
    print('  - ques_{:03d}'.format(index+1))
# Out:
#   - ques_001
#   - ques_002
#   - ques_003
#   - ques_004
#   - ques_005
#   - ques_006
#   - ques_007
#   - ques_008
#   - ques_009
#   - ques_010
#   - ques_011
#   - ques_012
#   - ques_013
#   - ques_014
#   - ques_015
#   - ques_016
#   - ques_017
#   - ques_018
#   - ques_019
#   - ques_020
#   - ques_021
#   - ques_022
#   - ques_023
#   - ques_024
#   - ques_025
#   - ques_026
#   - ques_027
#   - ques_028
#   - ques_029
#   - ques_030
#   - ques_031
#   - ques_032
#   - ques_033
#   - ques_034
#   - ques_035
#   - ques_036
#   - ques_037
#   - ques_038
#   - ques_039
#   - ques_040
#   - ques_041
#   - ques_042
#   - ques_043
#   - ques_044
#   - ques_045
#   - ques_046
#   - ques_047
#   - ques_048
#   - ques_049
#   - ques_050
#   - ques_051
#   - ques_052
#   - ques_053
#   - ques_054
#   - ques_055
#   - ques_056
#   - ques_057
#   - ques_058
#   - ques_059
#   - ques_060
#   - ques_061
#   - ques_062
#   - ques_063
#   - ques_064
#   - ques_065
#   - ques_066
# ...
